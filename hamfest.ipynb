# %%
# Importing the required libraries
import pandas as pd                        # For dataframes, reading html 
import matplotlib.pyplot as plt            # For Plotting

# %%
#Get current Delegate list from hamfest website
hams = pd.read_html('http://www.hamfestindia2018.com/Delegates/List?start=0&end=1500')[0]

# %%
hams
# Out:
#      Delegates List     Unnamed: 1 Unnamed: 2               Unnamed: 3  \
# 0                 #  Delegate Code   Callsign                     Name
# 1              1301       HFI00001     VU2ZRJ           Dr.Rajan Sinha
# 2              1302       HFI00002     VU3UEH            Dr.M Rangarao
# 3              1303       HFI00003     VU3ZHN              Samar Jynar
# 4              1304       HFI00004     VU3LOH                 K.Lohita
# 5              1305       HFI00005     VU3OXI              T Ravi Teja
# 6              1306       HFI00006     VU2TBM    T.B.M.Madhu Mohan Rao
# 7              1307       HFI00007     VU3ZKR                 K.Ramesh
# 8              1308       HFI00008     VU3HMB             Prakash Modh
# 9              1309       HFI00009     VU3OGP                  Snahail
# 10             1310       HFI00010     VU2JAU               Jayu Bhide
# 11             1311       HFI00011     VU2KOC               Om Prakash
# 12             1312       HFI00012        SWL             VU2KOC's XYL
# 13             1313       HFI00013     VU2BRJ                    Joshi
# 14             1314       HFI00014        SWL             VU2BRJ's XYL
# 15             1315       HFI00015     VU3WON                  Galgali
# 16             1316       HFI00016        SWL             VU3WON's XYL
# 17             1317       HFI00017      VU2OO                R.D.Gupta
# 18             1318       HFI00018     VU2OOO           Mrs Rani Gupta
# 19             1319       HFI00019     VU2EPT             Ernest Peter
# 20             1320       HFI00020     VU3AWI                Ramaswamy
# 21             1321       HFI00021     VU2ZMK                 Mahendra
# 22             1322       HFI00022     VU3YYO                   Arvind
# 23             1323       HFI00023      VU2FI           Dr.S.Sathyapal
# 24             1324       HFI00024        SWL                S.Lakshmi
# 25             1325       HFI00025     VU3SIM                S.Sowmini
# 26             1326       HFI00026     VU3HJC              Raghavendra
# 27             1327       HFI00027     VU2DEV                Ramprabhu
# 28             1328       HFI00028     VU2VTM               R.J.Marcus
# 29             1329       HFI00029     VU3UFF     Dr.Venka Shiva Reddy
# ...             ...            ...        ...                      ...
# 1279           2579       HFI01279     VU2LSW         Narayana Rao MPR
# 1280           2580       HFI01280        SWL      Dhanabal Nagendiran
# 1281           2581       HFI01281     VU3DYB               RAGESH P R
# 1282           2582       HFI01282     VU3SMZ              Mukundan S.
# 1283           2583       HFI01283     VU3ULH           Chetan Mandloi
# 1284           2584       HFI01284     VU3PQR       Raghu babu Peeriga
# 1285           2585       HFI01285        SWL           Rajini Peeriga
# 1286           2586       HFI01286        SWL          Balasubbhramani
# 1287           2587       HFI01287     VU2YLT     TEJAS YASHWANT LALIT
# 1288           2588       HFI01288     VU3JYC          Mohammed Asif T
# 1289           2589       HFI01289        SWL          SHANKAR JAYARAJ
# 1290           2590       HFI01290        SWL            ATHIRA SAJEEV
# 1291           2591       HFI01291     VU3OTJ            C.JEYALAKSHMI
# 1292           2592       HFI01292     VU3OTE               R GAYATHRI
# 1293           2593       HFI01293     VU3VRF            V RAMESHKUMAR
# 1294           2594       HFI01294     VU3OTF           M.A.PADMANABAN
# 1295           2595       HFI01295        SWL       Mohammed Saleh V K
# 1296           2596       HFI01296     VU2DOS     Dr.Prabhu Das Ankala
# 1297           2597       HFI01297     VU2ABS  Aravind Balasubramanian
# 1298           2598       HFI01298     VU2GRR        G R Rajarajeswari
# 1299           2599       HFI01299        SWL            Ajeya Aravind
# 1300           2600       HFI01300     VU3JVZ              N.S.SHARATH
# 1301           2601       HFI01301     VU2SVF           Subramanian S.
# 1302           2602       HFI01302        SWL           Seema Dadheech
# 1303           2603       HFI01303     VU2XPR            S.P.RAJENDRAN
# 1304           2604       HFI01304        SWL          ANITHARAJENDRAN
# 1305           2605       HFI01305     VU3CVQ         C.V.RAVICHANDRAN
# 1306           2606       HFI01306     VU2PGU      Pawan Kumar Agarwal
# 1307           2607       HFI01307     VU3OTN         K.V.RAMACHANDRAN
# 1308           2608       HFI01308        SWL            Team - VU3NOV
#
#       Unnamed: 4    Unnamed: 5      Unnamed: 6 Unnamed: 7
# 0         Gender          City           State    Country
# 1        Old Man           NaN             NaN      India
# 2        Old Man    Vijayawada  Andhra Pradesh      India
# 3        Old Man           NaN             NaN      India
# 4        Old Man    Vijayawada             NaN      India
# 5        Old Man           NaN             NaN      India
# 6        Old Man           NaN             NaN      India
# 7        Old Man           NaN             NaN      India
# 8        Old Man           NaN             NaN      India
# 9        Old Man           NaN             NaN      India
# 10       Old Man       Gwalior             NaN      India
# 11       Old Man      Belaguam             NaN      India
# 12    Young Lady      Belaguam             NaN      India
# 13       Old Man       Dharwad         Dharwad      India
# 14    Young Lady       DHARWAD       KARNATAKA      India
# 15       Old Man       Bijapur             NaN      India
# 16    Young Lady       Bijapur             NaN      India
# 17       Old Man           NaN             NaN      India
# 18    Young Lady           NaN             NaN      India
# 19       Old Man           NaN             NaN      India
# 20       Old Man           NaN             NaN      India
# 21       Old Man           NaN             Goa      India
# 22       Old Man           NaN             NaN      India
# 23       Old Man     Bengaluru       Karnataka      India
# 24    Young Lady     Bengaluru       Karnataka      India
# 25    Young Lady     Bengaluru       Karnataka      India
# 26       Old Man     Bengaluru       Karnataka      India
# 27       Old Man     Bengaluru       Karnataka      India
# 28       Old Man     Bengaluru       Karnataka      India
# 29       Old Man     Bengaluru       Karnataka      India
# ...          ...           ...             ...        ...
# 1279     Old Man       Chennai      Tamil Nadu      India
# 1280     Old Man      Dindigul       Tamilnadu      India
# 1281     Old Man     ERNAKULAM          KERALA      India
# 1282     Old Man       Chennai      Tamil Nadu      India
# 1283     Old Man     Bengaluru       Karnataka      India
# 1284     Old Man     Hyderabad       Telangana      India
# 1285  Young Lady     Hyderabad       Telangana      India
# 1286     Old Man     Bengaluru       Karnataka      India
# 1287     Old Man        MUMBAI     MAHARASHTRA      India
# 1288     Old Man     Bangalore       Karnataka      India
# 1289     Old Man    TRIVANDRUM          KERALA      India
# 1290  Young Lady    TRIVANDRUM          KERALA      India
# 1291  Young Lady   RAJAPALAYAM      TAMIL NADU      India
# 1292  Young Lady   RAJAPALAYAM      TAMIL NADU      India
# 1293     Old Man   RAJAPALAYAM      TAMIL NADU      India
# 1294     Old Man   RAJAPALAYAM      TAMIL NADU      India
# 1295     Old Man     Bangalore       Karnataka      India
# 1296     Old Man  Secunderabad       Telengana      India
# 1297     Old Man       Chennai      Tamil Nadu      India
# 1298  Young Lady       Chennai      Tamil Nadu      India
# 1299  Young Lady       Chennai      Tamil Nadu      India
# 1300     Old Man     Bangalore       Karnataka      India
# 1301     Old Man       Chennai      Tamil Nadu      India
# 1302  Young Lady     Bangalore       Karnataka      India
# 1303     Old Man    Kumbakonam       Tamilnadu      India
# 1304  Young Lady    Kumbakonam       Tamilnadu      India
# 1305     Old Man    Kumbakonam       Tamilnadu      India
# 1306     Old Man     Sambalpur          Odisha      India
# 1307     Old Man         KOCHI          KERALA      India
# 1308     Old Man     Bangalore       Karnataka      India
#
# [1309 rows x 8 columns]

# %%
#Just formatting the dataframe properly
hams = hams.rename(columns=hams.iloc[0])
hams = hams.drop([0])
hams
# Out:
#          # Delegate Code Callsign                     Name      Gender  \
# 1     1301      HFI00001   VU2ZRJ           Dr.Rajan Sinha     Old Man
# 2     1302      HFI00002   VU3UEH            Dr.M Rangarao     Old Man
# 3     1303      HFI00003   VU3ZHN              Samar Jynar     Old Man
# 4     1304      HFI00004   VU3LOH                 K.Lohita     Old Man
# 5     1305      HFI00005   VU3OXI              T Ravi Teja     Old Man
# 6     1306      HFI00006   VU2TBM    T.B.M.Madhu Mohan Rao     Old Man
# 7     1307      HFI00007   VU3ZKR                 K.Ramesh     Old Man
# 8     1308      HFI00008   VU3HMB             Prakash Modh     Old Man
# 9     1309      HFI00009   VU3OGP                  Snahail     Old Man
# 10    1310      HFI00010   VU2JAU               Jayu Bhide     Old Man
# 11    1311      HFI00011   VU2KOC               Om Prakash     Old Man
# 12    1312      HFI00012      SWL             VU2KOC's XYL  Young Lady
# 13    1313      HFI00013   VU2BRJ                    Joshi     Old Man
# 14    1314      HFI00014      SWL             VU2BRJ's XYL  Young Lady
# 15    1315      HFI00015   VU3WON                  Galgali     Old Man
# 16    1316      HFI00016      SWL             VU3WON's XYL  Young Lady
# 17    1317      HFI00017    VU2OO                R.D.Gupta     Old Man
# 18    1318      HFI00018   VU2OOO           Mrs Rani Gupta  Young Lady
# 19    1319      HFI00019   VU2EPT             Ernest Peter     Old Man
# 20    1320      HFI00020   VU3AWI                Ramaswamy     Old Man
# 21    1321      HFI00021   VU2ZMK                 Mahendra     Old Man
# 22    1322      HFI00022   VU3YYO                   Arvind     Old Man
# 23    1323      HFI00023    VU2FI           Dr.S.Sathyapal     Old Man
# 24    1324      HFI00024      SWL                S.Lakshmi  Young Lady
# 25    1325      HFI00025   VU3SIM                S.Sowmini  Young Lady
# 26    1326      HFI00026   VU3HJC              Raghavendra     Old Man
# 27    1327      HFI00027   VU2DEV                Ramprabhu     Old Man
# 28    1328      HFI00028   VU2VTM               R.J.Marcus     Old Man
# 29    1329      HFI00029   VU3UFF     Dr.Venka Shiva Reddy     Old Man
# 30    1330      HFI00030   VU2ZUB              Subramanyam     Old Man
# ...    ...           ...      ...                      ...         ...
# 1279  2579      HFI01279   VU2LSW         Narayana Rao MPR     Old Man
# 1280  2580      HFI01280      SWL      Dhanabal Nagendiran     Old Man
# 1281  2581      HFI01281   VU3DYB               RAGESH P R     Old Man
# 1282  2582      HFI01282   VU3SMZ              Mukundan S.     Old Man
# 1283  2583      HFI01283   VU3ULH           Chetan Mandloi     Old Man
# 1284  2584      HFI01284   VU3PQR       Raghu babu Peeriga     Old Man
# 1285  2585      HFI01285      SWL           Rajini Peeriga  Young Lady
# 1286  2586      HFI01286      SWL          Balasubbhramani     Old Man
# 1287  2587      HFI01287   VU2YLT     TEJAS YASHWANT LALIT     Old Man
# 1288  2588      HFI01288   VU3JYC          Mohammed Asif T     Old Man
# 1289  2589      HFI01289      SWL          SHANKAR JAYARAJ     Old Man
# 1290  2590      HFI01290      SWL            ATHIRA SAJEEV  Young Lady
# 1291  2591      HFI01291   VU3OTJ            C.JEYALAKSHMI  Young Lady
# 1292  2592      HFI01292   VU3OTE               R GAYATHRI  Young Lady
# 1293  2593      HFI01293   VU3VRF            V RAMESHKUMAR     Old Man
# 1294  2594      HFI01294   VU3OTF           M.A.PADMANABAN     Old Man
# 1295  2595      HFI01295      SWL       Mohammed Saleh V K     Old Man
# 1296  2596      HFI01296   VU2DOS     Dr.Prabhu Das Ankala     Old Man
# 1297  2597      HFI01297   VU2ABS  Aravind Balasubramanian     Old Man
# 1298  2598      HFI01298   VU2GRR        G R Rajarajeswari  Young Lady
# 1299  2599      HFI01299      SWL            Ajeya Aravind  Young Lady
# 1300  2600      HFI01300   VU3JVZ              N.S.SHARATH     Old Man
# 1301  2601      HFI01301   VU2SVF           Subramanian S.     Old Man
# 1302  2602      HFI01302      SWL           Seema Dadheech  Young Lady
# 1303  2603      HFI01303   VU2XPR            S.P.RAJENDRAN     Old Man
# 1304  2604      HFI01304      SWL          ANITHARAJENDRAN  Young Lady
# 1305  2605      HFI01305   VU3CVQ         C.V.RAVICHANDRAN     Old Man
# 1306  2606      HFI01306   VU2PGU      Pawan Kumar Agarwal     Old Man
# 1307  2607      HFI01307   VU3OTN         K.V.RAMACHANDRAN     Old Man
# 1308  2608      HFI01308      SWL            Team - VU3NOV     Old Man
#
#               City           State Country
# 1              NaN             NaN   India
# 2       Vijayawada  Andhra Pradesh   India
# 3              NaN             NaN   India
# 4       Vijayawada             NaN   India
# 5              NaN             NaN   India
# 6              NaN             NaN   India
# 7              NaN             NaN   India
# 8              NaN             NaN   India
# 9              NaN             NaN   India
# 10         Gwalior             NaN   India
# 11        Belaguam             NaN   India
# 12        Belaguam             NaN   India
# 13         Dharwad         Dharwad   India
# 14         DHARWAD       KARNATAKA   India
# 15         Bijapur             NaN   India
# 16         Bijapur             NaN   India
# 17             NaN             NaN   India
# 18             NaN             NaN   India
# 19             NaN             NaN   India
# 20             NaN             NaN   India
# 21             NaN             Goa   India
# 22             NaN             NaN   India
# 23       Bengaluru       Karnataka   India
# 24       Bengaluru       Karnataka   India
# 25       Bengaluru       Karnataka   India
# 26       Bengaluru       Karnataka   India
# 27       Bengaluru       Karnataka   India
# 28       Bengaluru       Karnataka   India
# 29       Bengaluru       Karnataka   India
# 30       Bengaluru       Karnataka   India
# ...            ...             ...     ...
# 1279       Chennai      Tamil Nadu   India
# 1280      Dindigul       Tamilnadu   India
# 1281     ERNAKULAM          KERALA   India
# 1282       Chennai      Tamil Nadu   India
# 1283     Bengaluru       Karnataka   India
# 1284     Hyderabad       Telangana   India
# 1285     Hyderabad       Telangana   India
# 1286     Bengaluru       Karnataka   India
# 1287        MUMBAI     MAHARASHTRA   India
# 1288     Bangalore       Karnataka   India
# 1289    TRIVANDRUM          KERALA   India
# 1290    TRIVANDRUM          KERALA   India
# 1291   RAJAPALAYAM      TAMIL NADU   India
# 1292   RAJAPALAYAM      TAMIL NADU   India
# 1293   RAJAPALAYAM      TAMIL NADU   India
# 1294   RAJAPALAYAM      TAMIL NADU   India
# 1295     Bangalore       Karnataka   India
# 1296  Secunderabad       Telengana   India
# 1297       Chennai      Tamil Nadu   India
# 1298       Chennai      Tamil Nadu   India
# 1299       Chennai      Tamil Nadu   India
# 1300     Bangalore       Karnataka   India
# 1301       Chennai      Tamil Nadu   India
# 1302     Bangalore       Karnataka   India
# 1303    Kumbakonam       Tamilnadu   India
# 1304    Kumbakonam       Tamilnadu   India
# 1305    Kumbakonam       Tamilnadu   India
# 1306     Sambalpur          Odisha   India
# 1307         KOCHI          KERALA   India
# 1308     Bangalore       Karnataka   India
#
# [1308 rows x 8 columns]

# %%
hams['Gender']
# Out:
# 1          Old Man
# 2          Old Man
# 3          Old Man
# 4          Old Man
# 5          Old Man
# 6          Old Man
# 7          Old Man
# 8          Old Man
# 9          Old Man
# 10         Old Man
# 11         Old Man
# 12      Young Lady
# 13         Old Man
# 14      Young Lady
# 15         Old Man
# 16      Young Lady
# 17         Old Man
# 18      Young Lady
# 19         Old Man
# 20         Old Man
# 21         Old Man
# 22         Old Man
# 23         Old Man
# 24      Young Lady
# 25      Young Lady
# 26         Old Man
# 27         Old Man
# 28         Old Man
# 29         Old Man
# 30         Old Man
#            ...
# 1279       Old Man
# 1280       Old Man
# 1281       Old Man
# 1282       Old Man
# 1283       Old Man
# 1284       Old Man
# 1285    Young Lady
# 1286       Old Man
# 1287       Old Man
# 1288       Old Man
# 1289       Old Man
# 1290    Young Lady
# 1291    Young Lady
# 1292    Young Lady
# 1293       Old Man
# 1294       Old Man
# 1295       Old Man
# 1296       Old Man
# 1297       Old Man
# 1298    Young Lady
# 1299    Young Lady
# 1300       Old Man
# 1301       Old Man
# 1302    Young Lady
# 1303       Old Man
# 1304    Young Lady
# 1305       Old Man
# 1306       Old Man
# 1307       Old Man
# 1308       Old Man
# Name: Gender, Length: 1308, dtype: object

# %%
gend = hams['Gender'].value_counts()
fig1,ax1 = plt.subplots()
ax1.pie(gend, explode = (0,0.2), autopct='%1.2f%%',
       shadow = True, startangle = 20)
ax1.legend(('Old Man','Young Lady'),title ='Gender', loc = 'lower right',bbox_to_anchor = (1,0,0.1,1))
ax1.axis('equal')
fig1.set_figheight(6)
fig1.set_figwidth(6)
plt.title("Hamfest 2018 Gender Breakdown", fontdict= {'fontsize': 16,
                                     'fontweight' : 5,
                                     'verticalalignment': 'baseline','horizontalalignment': 'center'})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-70be4fba60e6> in <module>()
# ----> 1 gend = hams['Gender'].value_counts()
#       2 fig1,ax1 = plt.subplots()
#       3 ax1.pie(gend, explode = (0,0.2), autopct='%1.2f%%',
#       4        shadow = True, startangle = 20)
#       5 ax1.legend(('Old Man','Young Lady'),title ='Gender', loc = 'lower right',bbox_to_anchor = (1,0,0.1,1))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'

# %%
# Correcting all the various conflicting state names,
# You might think why I didn't just convert everything to same case and then 
#
#
#
refined_hams = hams['State'].replace(["Dharwad", "Tamilnadu","KARNATAKA","karnataka","KERALA","ANDHRA PRADESH","TAMIL NADU",
                                      "TAMILNADU","Telengana","GUJRAT","GUJARAT","MAHARASHTRA","WEST BENGAL",
                                     "ANDHRAPRADESH","TELANGANA","KERALA STATE","Tamil nadu","Maharastra","KARANTAKA",
                                      "kerala","tamil nadu","KARANATAKA","Andhrapradesh","Tamilandu","KARANATKA",
                                     "TN","Tamilnadu ,Trichy 620004.","ODISHA",'MAHARASTRA','ANDRA PRADESH',
                                     "MANGALAPURAM ROAD","Near Kerala Govt. NGO Quarters",'UTTAR PRADESH','DELHI',"Gujrat",
                                     "Near Grindwell Norton","telangana",'BIHAR',"Maharasatra"],
                      ["Karnataka", "Tamil Nadu","Karnataka","Karnataka","Kerala","Andhra Pradesh","Tamil Nadu",
                       "Tamil Nadu","Telangana","Gujarat","Gujarat","Maharastra","West Bengal",
                      "Andhra Pradesh","Telangana","Kerala","Tamil Nadu","Maharastra","Karnataka",
                       "Kerala","Tamil Nadu", "Karnataka","Andhra Pradesh","Tamil Nadu","Karnataka",
                       "Tamil Nadu","Tamil Nadu","Odisha","Maharastra","Andhra Pradesh",
                       "Kerala","Kerala",'Uttar Pradesh',"Delhi","Gujarat",
                       "Karnataka","Telangana",'Bihar',"Maharastra"
                      ])
refined_hams
# Out:
# 1                  NaN
# 2       Andhra Pradesh
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13           Karnataka
# 14           Karnataka
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 Goa
# 22                 NaN
# 23           Karnataka
# 24           Karnataka
# 25           Karnataka
# 26           Karnataka
# 27           Karnataka
# 28           Karnataka
# 29           Karnataka
# 30           Karnataka
#              ...
# 1279        Tamil Nadu
# 1280        Tamil Nadu
# 1281            Kerala
# 1282        Tamil Nadu
# 1283         Karnataka
# 1284         Telangana
# 1285         Telangana
# 1286         Karnataka
# 1287        Maharastra
# 1288         Karnataka
# 1289            Kerala
# 1290            Kerala
# 1291        Tamil Nadu
# 1292        Tamil Nadu
# 1293        Tamil Nadu
# 1294        Tamil Nadu
# 1295         Karnataka
# 1296         Telangana
# 1297        Tamil Nadu
# 1298        Tamil Nadu
# 1299        Tamil Nadu
# 1300         Karnataka
# 1301        Tamil Nadu
# 1302         Karnataka
# 1303        Tamil Nadu
# 1304        Tamil Nadu
# 1305        Tamil Nadu
# 1306            Odisha
# 1307            Kerala
# 1308         Karnataka
# Name: State, Length: 1308, dtype: object

# %%
states = refined_hams.value_counts()
states
# Out:
# Karnataka         688
# Kerala            161
# Tamil Nadu        160
# Andhra Pradesh     71
# Maharashtra        51
# Telangana          32
# Gujarat            26
# Maharastra         26
# West Bengal        23
# Bihar               8
# USA                 7
# Uttar Pradesh       6
# Rajasthan           5
# Assam               3
# Jharkhand           3
# Puducherry          3
# Odisha              2
# Delhi               2
# Goa                 2
# ONTARIO             2
# Doha                1
# India               1
# New Delhi           1
# Chhattisgarh        1
# Madhya Pradesh      1
# Haryana             1
# Chicago             1
# Manipur             1
# Tripura             1
# Name: State, dtype: int64

# %%
states[9:].sum()
# Out:
# 52

# %%
major_states = states[:9]

# %%
major_states["Others"]= states[9:].sum()

# %%
major_states.index
# Out:
# Index(['Karnataka', 'Kerala', 'Tamil Nadu', 'Andhra Pradesh', 'Maharashtra',
#        'Telangana', 'Gujarat', 'Maharastra', 'West Bengal', 'Others'],
#       dtype='object')

# %%
fig1,ax1 = plt.subplots()
ax1.pie(major_states, explode = (0,0.05,0.03,0.06,0.07,0.08,0.09,0.1,0.1,0.1), autopct='%1.2f%%',
       shadow = True, startangle = 20)
ax1.legend(major_states.index,title ='State', loc = 'lower right',bbox_to_anchor = (1,0,0.1,1))
ax1.axis('equal')
fig1.set_figheight(10)
fig1.set_figwidth(10)
plt.title("Hamfest 2018 Statewise Breakdown", fontdict= {'fontsize': 20,
                                     'fontweight' : 1000,
                                     'verticalalignment': 'baseline','horizontalalignment': 'center'})
plt.show()

# %%
calls = list(hams["Callsign"])

# %%
calls
# Out:
# ['VU2ZRJ',
#  'VU3UEH',
#  'VU3ZHN',
#  'VU3LOH',
#  'VU3OXI',
#  'VU2TBM',
#  'VU3ZKR',
#  'VU3HMB',
#  'VU3OGP',
#  'VU2JAU',
#  'VU2KOC',
#  'SWL',
#  'VU2BRJ',
#  'SWL',
#  'VU3WON',
#  'SWL',
#  'VU2OO',
#  'VU2OOO',
#  'VU2EPT',
#  'VU3AWI',
#  'VU2ZMK',
#  'VU3YYO',
#  'VU2FI',
#  'SWL',
#  'VU3SIM',
#  'VU3HJC',
#  'VU2DEV',
#  'VU2VTM',
#  'VU3UFF',
#  'VU2ZUB',
#  'VU3SGQ',
#  'VU3WVN',
#  'VU3ZLS',
#  'SWL',
#  'VU2OEC',
#  'VU3NOV',
#  'VU2SJV',
#  'VU3HST',
#  'VU3YWK',
#  'VU3XBP',
#  'VU3 HRL',
#  'VU2JLY',
#  'VU3PWT',
#  'SWL',
#  'VU3IGP',
#  'VU3XEB',
#  'VU3NBD',
#  'VU3UPQ',
#  'VU3YWA',
#  'VU2MY',
#  'VU2MSB',
#  'VU3JUK',
#  'VU3URJ',
#  'VU3CGX',
#  'SWL',
#  'VU3NIX',
#  'VU3UNS',
#  'VU2VSJ',
#  'VU3UKD',
#  'VU3YMR',
#  'VU3JTN',
#  'VU3JUO',
#  'VU3MXT',
#  'VU3UVG',
#  'VU3WMG',
#  'VU3ZTQ',
#  'VU3AVW',
#  'VU3NEO',
#  'VU3IYR',
#  'VU2NEP',
#  'VU3UJW',
#  'VU3YBY',
#  'VU3XAO',
#  'VU2LDH',
#  'VU3GDS',
#  'VU2SDU',
#  'VU2COC',
#  'VU2YE',
#  'VU3VOC',
#  'VU2RIF',
#  'VU2ELD',
#  'VU2WMY',
#  'VU2LMP',
#  'VU3JYT',
#  'VU3JYU',
#  'VU3ONX',
#  'VU2JHM',
#  'VU3MYV',
#  'VU3OHT',
#  'VU3ULP',
#  'SWL',
#  'SWL',
#  'VU3SXE',
#  'SWL',
#  'SWL',
#  'VU2CAW',
#  'VU2NSL',
#  'VU3GHM',
#  'VU3GHN',
#  'VU3ONJ',
#  'VU3ONI',
#  'VU3PMU',
#  'SWL',
#  'VU3YYK',
#  'VU3JRG',
#  'VU3YYM',
#  'VU3YBC',
#  'VU2KPR',
#  'VU2CHR',
#  'VU3CJM',
#  'VU3JYP',
#  'SWL',
#  'VU3YHR',
#  'VU3TWR',
#  'VU3XHJ',
#  'VU3HDP',
#  'VU3MXR',
#  'VU2MSA',
#  'VU3TZL',
#  'VU3EDG',
#  'VU2QBX',
#  'VU2GMN',
#  'SWL',
#  'VU3XEG',
#  'VU3HSR',
#  'VU3SXZ',
#  'N9SFK',
#  'VU3YBU',
#  'VU3MET',
#  'VU2 SET',
#  'VU2 HSM',
#  'VU3WLL',
#  'KD0NER',
#  'VU2KLG',
#  'VU3DEW',
#  'VU2SBJ',
#  'VU3RXN',
#  'VU2DJM',
#  'VU3JOB',
#  'VU3UJX',
#  'SWL',
#  'VU2NSK',
#  'VU2OJ',
#  'VU3OFO',
#  'VU3BUH',
#  'VU3BUJ',
#  'VU3JAJ',
#  'SWL',
#  'SWL',
#  'VU3ULQ',
#  'VU3KOL',
#  'SWL',
#  'VU2KPU',
#  'VU3SYL',
#  'VU3VXJ',
#  'VU3PNN',
#  'VU3CKP',
#  'VU2CJC',
#  'VU3KHR',
#  'VU2OJK',
#  'VU2JRT',
#  'VU3KLP',
#  'VU2AZS',
#  'VU3UMD',
#  'VU2GRM',
#  'VU2ENT',
#  'VU3DNG',
#  'VU3XEK',
#  'VU2KIZ & K',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU2IKX',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU2ALI',
#  'SWL',
#  'SWL',
#  'VU2EZJ',
#  'VU2MBU',
#  'VU3JVY',
#  'VU3ULU',
#  'SWL',
#  'VU2EZK',
#  'VU3GOU',
#  'VU3JXR',
#  'VU3JXS',
#  'SWL',
#  'VU3UNL',
#  'SWL',
#  'VU3VYI',
#  'VU3HCJ',
#  'VU2EZH',
#  'VU3OCR',
#  'VU3OCS',
#  'VU3GBC',
#  'VU3USG',
#  'VU3XFE',
#  'VU3XMA',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3ULB',
#  'SWL',
#  'VU3JVJ',
#  'VU3JYK',
#  'VU2ACK',
#  'VU3TGD',
#  'VU3UKR',
#  'VU3TYG',
#  'VU3YWP',
#  'VU2QDX',
#  'QRP (VU2QD',
#  'XYL (VU2QD',
#  'VU3YBR',
#  'SWL',
#  'VU3VJL',
#  'VU3SZJ',
#  'VU3YWW',
#  'VU3KTW',
#  'VU3ONR',
#  'VU2JLE',
#  'VU2TCA',
#  'VU2WAG',
#  'VU2DWA',
#  'SWL',
#  'SWL',
#  'VU2VJT',
#  'VU3MDO',
#  'VU2NYK',
#  'VU3HBC',
#  'VU2BGH',
#  'VU2VMJ',
#  'VU2RAK',
#  'VU2KD',
#  'VU2AIT',
#  'VU3RGB',
#  'VU3MWZ',
#  'VU2GRB',
#  'VU3WRL',
#  'VU3UFU',
#  'VU2TTW',
#  'VU3CRI',
#  'SWL',
#  'VU3JTC',
#  'VU3UNY',
#  'VU3OGW',
#  'VU2OID',
#  'VU2ACD',
#  'VU2JME',
#  'VU3WJN',
#  'VU3BCN',
#  'VU3BJZ',
#  'SWL',
#  'SWL',
#  'VU2BBE',
#  'VA3UMA',
#  'VA3RNY',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3OTK',
#  'VU3UNX',
#  'VU3ZTN',
#  'VU3UPF',
#  'VU2MIK',
#  'VU3UST',
#  'VU3UJO',
#  'VU3BJN',
#  'VU3CGJ',
#  'VU3UMQ',
#  'VU3VXX',
#  'VU2TCE',
#  'VU2ISR',
#  'SWL',
#  'VU3SXL',
#  'VU3PZA',
#  'VU3JBE',
#  'VU2VNK',
#  'SWL',
#  'VU2THF',
#  'VU3ITI',
#  'VU2PTR',
#  'VU2DH',
#  'VU3OEL',
#  'VU3KIT',
#  'VU3BGK',
#  'VU3IBA',
#  'VU2RDX',
#  'VU2ETO',
#  'VU2LF',
#  'VU3HPG',
#  'VU2AIV',
#  'VU2BWN',
#  'SWL',
#  'SWL',
#  'VU3AWP',
#  'VU3ODX',
#  'VU2VKT',
#  'VU2SBU',
#  'VU2KRE',
#  'VU3UOA',
#  'VU3NYD',
#  'VU3XQG',
#  'VU3TXE',
#  'VU3UPG',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3HNG',
#  'VU2ZRK',
#  'VU2MCL',
#  'SWL',
#  'SWL',
#  'VU3YGD',
#  'VU3OSV',
#  'SWL',
#  'VU3VTJ',
#  'VU2XJT',
#  'SWL',
#  'SWL',
#  'VU2JVJ',
#  'VU3BUT',
#  'SWL',
#  'VU3XEF',
#  'VU3TBS',
#  'VU2MIE',
#  'VU3TJA',
#  'VU3HEA',
#  'VU2TPC',
#  'VU3GEI',
#  'VU3ITQ',
#  'VU3ECN',
#  'VU3OXW',
#  'VU2XPN',
#  'VU3XEI',
#  'VU3VWZ',
#  'VU2RMS',
#  'VU3RRN',
#  'VU3LLY',
#  'VU2NNN',
#  'VU2PGB',
#  'VU3RQN',
#  'VU3UHH',
#  'VU2JKR',
#  'VU2RDL',
#  'VU2GMK',
#  'VU2SYT',
#  'VU3MTY',
#  'VU2KGN',
#  'VU2BOS',
#  'VU3BRW',
#  'SWL',
#  'VU2DCC',
#  'VU3RLN',
#  'VU2HDC',
#  'VU3VOV',
#  'VU3YYH',
#  'VU2MTS',
#  'VU3VXT',
#  'VU2RPC',
#  'VU3ONV',
#  'VU3RZD',
#  'SWL',
#  'VU2EZD',
#  'VU3VYD',
#  'VU3UPM',
#  'SWL',
#  'SWL',
#  'VU2ZNN',
#  'SWL',
#  'VU3UFS',
#  'SWL',
#  'VU2ECY',
#  'VU3EAP',
#  'VU3CXB',
#  'SWL',
#  'VU2CPV',
#  'VU3TXA',
#  'VU3BNE',
#  'VU3UIT',
#  'VU3MBV',
#  'VU30ID',
#  'VU2KHC',
#  'SWL',
#  'VU3RCT',
#  'VU3XEP',
#  'VU3WRA',
#  'VU3UYR',
#  'SWL',
#  'VU3VIU',
#  'VU3VTK',
#  'VU2MYH',
#  'VU2MYN',
#  'VU2BL',
#  'VU3VIP',
#  'VU2ARG',
#  'VU2ADV',
#  'VU3XQH',
#  'VU2WAP',
#  'VU3NOP',
#  'VU3NOU',
#  'VU3ZPK',
#  'VU3VSD',
#  'VU3STD',
#  'SWL',
#  'VU3BOJ',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3NOH',
#  'VU3UJZ',
#  'VU3DJS',
#  'VU3YBO',
#  'SWL',
#  'SWL',
#  'VU2DPE',
#  'VU3DON',
#  'VU3WIS',
#  'VU2WDH',
#  'VU3TNL',
#  'VU2UJA',
#  'VU3XRR',
#  'VU3KOD',
#  'SWL',
#  'SWL',
#  'VU3EDS',
#  'VU2OTD',
#  'VU2JTC',
#  'VU2XYU',
#  'VU2ZOG',
#  'VU2GZ',
#  'VU2WGO',
#  'SWL',
#  'VU2OY',
#  'VU3RCM',
#  'VU3JFL',
#  'VU3ECM',
#  'SWL',
#  'VU2LU',
#  'VU3WMZ',
#  'VU3ZTP',
#  'VU3MYP',
#  'VU2HNA',
#  'VU3TGK',
#  'VU3BNH',
#  'VU3PAL',
#  'VU2PAJ',
#  'VU2DXJ',
#  'VU3JJV',
#  'VU2HRF',
#  'VU2ZRF',
#  'VU3RTY',
#  'SWL',
#  'VU2TQC',
#  'VU2KWJ',
#  'SWL',
#  'VU2TE',
#  'SWL',
#  'SWL',
#  'VU3TGN',
#  'VU2AKC',
#  'VU3HLE',
#  'SWL',
#  'VU3EQG',
#  'VU2TUO',
#  'VU2KWM',
#  'VU3ECK',
#  'VU2XE',
#  'SWL',
#  'VU3OUQ',
#  'SWL',
#  'VU3PMJ',
#  'VU2KKQ',
#  'SWL',
#  'VU2UYC',
#  'VU2JFA',
#  'VU3GNU',
#  'VU2EGM',
#  'VU2MGS',
#  'VU2PKH',
#  'VU2PLG',
#  'VU0020 SWL',
#  'VU3KUD',
#  'VU3DGU',
#  'VU3OCP',
#  'SWL',
#  'VU2KDJ',
#  'VU3CWB',
#  'VU3MYX',
#  'VU3RZG',
#  'VU2KYX',
#  'VU2LX',
#  'VU3ARQ',
#  'VU3NXI',
#  'VU2ICI',
#  'VU3EAA',
#  'VU2IXY',
#  'VU2GHX',
#  'VU2JIM',
#  'VU2JON',
#  'VU2VOH',
#  'SWL',
#  'VU2SEV',
#  'VU3YXS',
#  'VU3RZE',
#  'VU3JXV',
#  'VU2XMB',
#  'VU3VUH',
#  'VU3BRC',
#  'SWL',
#  'SWL',
#  'VU2RJR',
#  'VU3BCQ',
#  'VU2DLE',
#  'VU3SUI',
#  'VU2RET',
#  'VU3RBW',
#  'VU2JCP',
#  'VU2KLO',
#  'VU2GOG',
#  'VU3BOP',
#  'VU3WCI',
#  'VU3GEP',
#  'SWL',
#  'VU3SRE',
#  'VU3MHJ',
#  'VU2RCR',
#  'VU2SSC',
#  'VU2RO',
#  'VU3NTT',
#  'SWL',
#  'VU3UNW',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3YWB',
#  'VU2WWP',
#  'VU3DZZ',
#  'SWK',
#  'SWL',
#  'VU3GGK',
#  'VU3GSA',
#  'VU3CTA',
#  'VU2DEN',
#  'VU3UHL',
#  'VU3UHK',
#  'VU3MGL',
#  'VU3OUM',
#  'VU3CGC',
#  'VU3OGC',
#  'VU3OGQ',
#  'VU3ODD',
#  'VU3UNR',
#  'SWL',
#  'SWL',
#  'VU3BYD',
#  'SWL',
#  'VU3MOA',
#  'VU2VAU',
#  'VU2DRK',
#  'VU2MRK',
#  'VU3USI',
#  'VU3HDO',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3OUL',
#  'VU3STC',
#  'VU3XPY',
#  'VU3KET',
#  'VU3IBC',
#  'VU3VQP',
#  'VU3FWR',
#  'VU2NXS',
#  'VU2UJE',
#  'VU3RSI',
#  'VU3DYH',
#  'VU2BR',
#  'VU3 TBP',
#  'VU3JCJ',
#  'VU3WFO',
#  'VU3BOM',
#  'SWL',
#  'VU3JHU',
#  'VU3DGA',
#  'KD0NFG',
#  'VU2OWD',
#  'SWL',
#  'VU3ZUG',
#  'SWL',
#  'SWL',
#  'VU2PWD',
#  'SWL',
#  'SWL',
#  'VU2USA',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3ASN',
#  'VU3PIY',
#  'VU3DXT',
#  'SWL',
#  'SWL',
#  'VU3MOB',
#  'VU3VFD',
#  'VU2GTI',
#  'VU3TWW',
#  'VU3XVM',
#  'SWL',
#  'SWL',
#  'VU3CDX',
#  'VU3UFX',
#  'VU3UFT',
#  'VU3WEG',
#  'VU3CIT',
#  'VU3CIO',
#  'SWL',
#  'SWL',
#  'VU3BWB',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3RZO',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3OXH',
#  'VU3CHP',
#  'VU2RBI',
#  'VU2NRO2',
#  'VU2NRO3',
#  'VU2NRO4',
#  'VU2NRO5',
#  'VU2NRO6',
#  'VU2NRO7',
#  'VU2NAM',
#  'SWL',
#  'SWL',
#  'VU3EAB',
#  'VU2TNN',
#  'VU3UEN',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU2DUC',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3PSF',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3TAU',
#  'VU3YRM',
#  'VU2POL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3UPI',
#  'SWL',
#  'SWL',
#  'VU3BRR',
#  'VU3CSC',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3GPK',
#  'VU2RCY',
#  'VU3JRY',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3UPO',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3ECP',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3 OOH',
#  'SWL',
#  'VU3RUI',
#  'VU3ROR',
#  'VU3YBK',
#  'VU2LVJ',
#  'VU2ARZ',
#  'VU3MFA',
#  'SWL',
#  'VU3XJA',
#  'VU3DJO',
#  'VU3SQG',
#  'VU3ZBJ',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU2HNN',
#  'VU3XOU',
#  'SWL',
#  'VU3XOP',
#  'SWL',
#  'SWL',
#  'VU3HCC',
#  'SWL',
#  'VU3UFV',
#  'VU2 NDB',
#  'VU2 NTH',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3DHM',
#  'VU3DHI',
#  'SWL',
#  'VU3DHO',
#  'VU3RBH',
#  'VU2VEV',
#  'SWL',
#  'VU3NGP',
#  'VU3ITO',
#  'VU3JBI',
#  'VU2KSX',
#  'VU3VNN',
#  'VU3NWP',
#  'SWL',
#  'VU3HCR',
#  'VU3ICJ',
#  'VU3WCN',
#  'VU3DHN',
#  'VU3BIL',
#  'VU3ARG',
#  'VU3DQJ',
#  'SWL',
#  'SWL',
#  'VU3OSX',
#  'VU3 OSN',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3OFN',
#  'VU3KAZ',
#  'VU3WIC',
#  'VU3VNF',
#  'VU3GEA',
#  'VU3UBM',
#  'VU3SWG',
#  'VU3TGJ',
#  'VU3TLD',
#  'VU3DRU',
#  'VU3TGG',
#  'VU3SNV',
#  'VU3ITP',
#  'VU3GOJ',
#  'VU3SNY',
#  'VU3UDI',
#  'VU3GHO',
#  'VU3LIC',
#  'VU3YYA',
#  'SWL',
#  'VU2EZI',
#  'VU3SYF',
#  'SWL',
#  'VU3SMQ',
#  'VU3MWH',
#  'SWL',
#  'SWL',
#  'VU3UOB',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3XQI',
#  'VU2AJG',
#  'VU3ULC',
#  'VU3KMU',
#  'VU2TWZ',
#  'VU2HRI',
#  'SWL',
#  'VU2PEY',
#  'VU2BVN',
#  'VU3BLN',
#  'VU3SCC',
#  'VU3YSU',
#  'VU3YUP',
#  'VU2TKC',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3YPP',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU2COD',
#  'VU3GNL',
#  'VU2EYU',
#  'VU3OVK',
#  'VU3UNO',
#  'VU2VPR',
#  'VU3HDS',
#  'VU2ARL',
#  'VU3TEJ',
#  'VU3WBQ',
#  'VU2DSV',
#  'VU3REC',
#  'VU3XKC',
#  'VU3VYM',
#  'VU3LSU',
#  'VIT',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3KUI',
#  'VU3NNB',
#  'VU3AUH',
#  'VU3OPU',
#  'VU3ATN',
#  'VU3REM',
#  'SWL',
#  'VU2WDP',
#  'VU2ELJ',
#  'VU3RTO',
#  'SWL',
#  'VU3VXE',
#  'VU3BPQ',
#  'VU3NAW',
#  'VU3IFD',
#  'VU3NOZ',
#  'VU3RWB',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SW',
#  'VU3VFF',
#  'SWL',
#  'VU2RVK',
#  'VU3YSF',
#  'VU3RWI',
#  'VU3YMG',
#  'VU3UOM',
#  'SWL',
#  'VU3XIO',
#  'SWL',
#  'VU3SIO',
#  'SWL',
#  'SWL',
#  'VU3PTO',
#  'VU3SDZ',
#  'VU3XPB',
#  'VU2NGS',
#  'VU2 JLX',
#  'VU3UXJ',
#  'SWL',
#  'SWL',
#  'VU2DVW',
#  'VU3KHO',
#  'VU3FSI',
#  'VU2JBM',
#  'SWL',
#  'VU3CYA',
#  'VU3IUA',
#  'VU2MBA',
#  'VU3SXH',
#  'SWL',
#  'VU2JA',
#  'VU2IDB',
#  'VU2SXC',
#  'VU2GJP',
#  'SWL',
#  'SWL',
#  'VU3XFD',
#  'VU3ULF',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU2AEH',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'SWL',
#  'VU3BCE',
#  ...]

# %%
calls2 = calls[:]
for i in calls:
    if "VU3" in i or "VU2" in i or "SWL" in i or "SLW" in i or "SWK" in i or "SW" == i:
        calls2.remove(i)
print("Notable callsigns not in VU2 and VU3 Series: ", calls2)
# Out:
# Notable callsigns not in VU2 and VU3 Series:  ['N9SFK', 'KD0NER', 'VA3UMA', 'VA3RNY', 'KD0NFG', 'VIT', 'KC9ZJX', 'KD9LLR', 'KC9ZJG']

# %%
vu2 = 0
vu3 = 0
SWL = 0
for i in calls:
    if "VU2" in i:
        vu2 = vu2 + 1
    elif "VU3" in i:
        vu3 = vu3 + 1
    elif "SWL" in i or "SLW" in i or "SWK" in i or "SW" == i:
        SWL = SWL + 1
print("Hams with VU2 Callsigns:   ", vu2,"\nHams with VU3 Callsigns:   ",vu3,"\nShortwave listners(SWLs):  ",
      SWL,"\nHams with Other Callsigns: ",len(calls)-vu2-vu3-SWL)
# Out:
# Hams with VU2 Callsigns:    304
# Hams with VU3 Callsigns:    523
# Shortwave listners(SWLs):   472
# Hams with Other Callsigns:  9

# %%
fig1,ax1 = plt.subplots()
ax1.bar(["VU2s","VU3s","SWLs","Others"],[vu2,vu3,SWL,len(calls)-vu2-vu3-SWL])
plt.xlabel("Callsigns")
plt.ylabel("Number of Hams")
fig1.set_figheight(7)
fig1.set_figwidth(7)
plt.show()
